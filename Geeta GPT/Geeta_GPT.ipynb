# %%
with open('Bhagwad Geeta.txt', 'r', encoding = 'utf-8') as f:
    text = f.read()

# %%
print('length of geeta text: ', len(text))
# Out:
# length of geeta text:  112679

# %%
print(text[:1000])
# Out:
# CHAPTER I
# Dhritirashtra:
# Ranged thus for battle on the sacred plain--
# On Kurukshetra--say, Sanjaya! say
# What wrought my people, and the Pandavas?
# Sanjaya:
# When he beheld the host of Pandavas,
# Raja Duryodhana to Drona drew,
# And spake these words: "Ah, Guru! see this line,
# How vast it is of Pandu fighting-men,
# Embattled by the son of Drupada,
# Thy scholar in the war! Therein stand ranked
# Chiefs like Arjuna, like to Bhima chiefs,
# Benders of bows; Virata, Yuyudhan,
# Drupada, eminent upon his car,
# Dhrishtaket, Chekitan, Kasi's stout lord,
# Purujit, Kuntibhoj, and Saivya,
# With Yudhamanyu, and Uttamauj
# Subhadra's child; and Drupadi's;-all famed!
# All mounted on their shining chariots!
# On our side, too,--thou best of Brahmans! see
# Excellent chiefs, commanders of my line,
# Whose names I joy to count: thyself the first,
# Then Bhishma, Karna, Kripa fierce in fight,
# Vikarna, Aswatthaman; next to these
# Strong Saumadatti, with full many more
# ...

# %%
import re
review = re.sub('[^a-zA-Z]', ' ', text)
review = review.split()
review
# Out:
# ['CHAPTER',
#  'I',
#  'Dhritirashtra',
#  'Ranged',
#  'thus',
#  'for',
#  'battle',
#  'on',
#  'the',
#  'sacred',
#  'plain',
#  'On',
#  'Kurukshetra',
#  'say',
#  'Sanjaya',
#  'say',
#  'What',
#  'wrought',
#  'my',
#  'people',
#  'and',
#  'the',
#  'Pandavas',
#  'Sanjaya',
#  'When',
#  'he',
#  'beheld',
#  'the',
#  'host',
#  'of',
#  'Pandavas',
#  'Raja',
#  'Duryodhana',
#  'to',
#  'Drona',
#  'drew',
#  'And',
#  'spake',
#  'these',
#  'words',
#  'Ah',
#  'Guru',
#  'see',
#  'this',
#  'line',
#  'How',
#  'vast',
#  'it',
#  'is',
#  'of',
#  'Pandu',
#  'fighting',
#  'men',
#  'Embattled',
#  'by',
#  'the',
#  'son',
#  'of',
#  'Drupada',
#  'Thy',
#  'scholar',
#  'in',
#  'the',
#  'war',
#  'Therein',
#  'stand',
#  'ranked',
#  'Chiefs',
#  'like',
#  'Arjuna',
#  'like',
#  'to',
#  'Bhima',
#  'chiefs',
#  'Benders',
#  'of',
#  'bows',
#  'Virata',
#  'Yuyudhan',
#  'Drupada',
#  'eminent',
#  'upon',
#  'his',
#  'car',
#  'Dhrishtaket',
# ...

# %%
chars = sorted(list(set(review)))
print(' '.join(chars))
# Out:
# A ADHIBHUTA ADHIDAIVA ADHIYAJNA ADHYATMAN AKSHARAM ASAT Abandoning Abode Above Abstaining Abstention According Aches Aching Act Acting Action Adhyatman Adityas Adore Adoring After Again Against Age Agni Ah Ahinsa Aho Ahovat Airavata Aksharaparabrahmayog Albeit Aliens All Almighty Alms Alone Always Am Amid Amrit An Ananta Ancestor Ancient And Another Any Archer Are Arise Arjun Arjuna Armed Art Aryam As Asat Asita Asuras Aswattha Aswatthaman Aswins At Atman Atmasanyamayog Attain Attaining Attraction Avarice Awaits Awful BHAGAVAD BRAHM BRAHMA Back Banishing Banyan Barring Be Bear Bears Because Becoming Beginneth Beginning Behold Beholding Being Beings Believing Belongs Benders Bent Best Better Between Betwixt Beyond Bhaktiyog Bharata Bharatas Bhima Bhishma Bhrigu Bhutas Bhuts Bind Binds Birth Birthless Bitter Blessing Blest Blew Blight Blind Blinding Blowing Blue Body Book Born Both Boundless Brahm Brahma Brahmacharya Brahman Brahmans Breaks Breathing Breaths Bring Bringer Bringing Brin
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#       2 review = ' '.join(review)
#
# Input In [7], in <listcomp>(.0)
# ----> 1 review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
#       2 review = ' '.join(review)
#
# NameError: name 'stopwords' is not defined
